# %%
import pandas as pd

# %%
series_1=pd.Series([1,2,3,4,5])

# %%
series_2=pd.Series(['a','b','c','d','e'])

# %%
df=pd.concat([series_1,series_2])

# %%
df
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
df=pd.concat([series_1,series_2],axis=1)

# %% [raw]
# df

# %%
series_3=pd.Series(['ab','cd','ef','gh','ij'])

# %%
series_3
# Out:
# 0    ab
# 1    cd
# 2    ef
# 3    gh
# 4    ij
# dtype: object

# %%
df
# Out:
#    0  1
# 0  1  a
# 1  2  b
# 2  3  c
# 3  4  d
# 4  5  e

# %%
df=pd.concat([series_1,series_2,series_3], axis=1)

# %%
df
# Out:
#    0  1   2
# 0  1  a  ab
# 1  2  b  cd
# 2  3  c  ef
# 3  4  d  gh
# 4  5  e  ij

# %%
df=pd.DataFrame({'num':series_1,
                 'letters':series_2})

# %%
series_1,series_2
# Out:
# (0    1
#  1    2
#  2    3
#  3    4
#  4    5
#  dtype: int64,
#  0    a
#  1    b
#  2    c
#  3    d
#  4    e
#  dtype: object)

# %%
df
# Out:
#    num letters
# 0    1       a
# 1    2       b
# 2    3       c
# 3    4       d
# 4    5       e

# %%
df2=pd.DataFrame({'num': series_1,
                'letters': series_2,
                'strings': series_3})

# %% [raw]
# df2

# %%
df2
# Out:
#    num letters strings
# 0    1       a      ab
# 1    2       b      cd
# 2    3       c      ef
# 3    4       d      gh
# 4    5       e      ij

# %%
hour=pd.read_csv('D:\BA\Data Analysis\Data Analysis Practise Project\hour.csv')

# %%
hour
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
hour.head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
# 5        6  2011-01-01       1   0     1   5        0        6           0
# 6        7  2011-01-01       1   0     1   6        0        6           0
# 7        8  2011-01-01       1   0     1   7        0        6           0
# 8        9  2011-01-01       1   0     1   8        0        6           0
# 9       10  2011-01-01       1   0     1   9        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81     0.0000       3          13   16
# ...

# %%
hour.tail(10)
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17369    17370  2012-12-31       1   1    12  14        0        1
# 17370    17371  2012-12-31       1   1    12  15        0        1
# 17371    17372  2012-12-31       1   1    12  16        0        1
# 17372    17373  2012-12-31       1   1    12  17        0        1
# 17373    17374  2012-12-31       1   1    12  18        0        1
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17369           1           2  0.28  0.2727  0.45     0.2239      62
# 17370           1           2  0.28  0.2879  0.45     0.1343      69
# ...

# %%
hour.tail()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49

# %%
hour.Columns()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-96433a01fc0f> in <module>
# ----> 1 hour.Columns()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Columns'

# %%
hour.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
req_col=['dteday','temp','atemp','hum','windspeed','cnt']

# %%
hour = pd.read_csv('D:\BA\Data Analysis\Data Analysis Practise Project\hour.csv', usecols = req_col)

# %%
hour
# Out:
#            dteday  temp   atemp   hum  windspeed  cnt
# 0      2011-01-01  0.24  0.2879  0.81     0.0000   16
# 1      2011-01-01  0.22  0.2727  0.80     0.0000   40
# 2      2011-01-01  0.22  0.2727  0.80     0.0000   32
# 3      2011-01-01  0.24  0.2879  0.75     0.0000   13
# 4      2011-01-01  0.24  0.2879  0.75     0.0000    1
# ...           ...   ...     ...   ...        ...  ...
# 17374  2012-12-31  0.26  0.2576  0.60     0.1642  119
# 17375  2012-12-31  0.26  0.2576  0.60     0.1642   89
# 17376  2012-12-31  0.26  0.2576  0.60     0.1642   90
# 17377  2012-12-31  0.26  0.2727  0.56     0.1343   61
# 17378  2012-12-31  0.26  0.2727  0.65     0.1343   49
#
# [17379 rows x 6 columns]

# %%
hour = pd.read_csv('D:\BA\Data Analysis\Data Analysis Practise Project\hour.csv', usecols = req_col, decimal =',')

# %%
hour
# Out:
#            dteday  temp   atemp   hum windspeed  cnt
# 0      2011-01-01  0.24  0.2879  0.81         0   16
# 1      2011-01-01  0.22  0.2727   0.8         0   40
# 2      2011-01-01  0.22  0.2727   0.8         0   32
# 3      2011-01-01  0.24  0.2879  0.75         0   13
# 4      2011-01-01  0.24  0.2879  0.75         0    1
# ...           ...   ...     ...   ...       ...  ...
# 17374  2012-12-31  0.26  0.2576   0.6    0.1642  119
# 17375  2012-12-31  0.26  0.2576   0.6    0.1642   89
# 17376  2012-12-31  0.26  0.2576   0.6    0.1642   90
# 17377  2012-12-31  0.26  0.2727  0.56    0.1343   61
# 17378  2012-12-31  0.26  0.2727  0.65    0.1343   49
#
# [17379 rows x 6 columns]

# %%
hour.head()
# Out:
#        dteday  temp   atemp   hum windspeed  cnt
# 0  2011-01-01  0.24  0.2879  0.81         0   16
# 1  2011-01-01  0.22  0.2727   0.8         0   40
# 2  2011-01-01  0.22  0.2727   0.8         0   32
# 3  2011-01-01  0.24  0.2879  0.75         0   13
# 4  2011-01-01  0.24  0.2879  0.75         0    1

# %%
hour.tail()
# Out:
#            dteday  temp   atemp   hum windspeed  cnt
# 17374  2012-12-31  0.26  0.2576   0.6    0.1642  119
# 17375  2012-12-31  0.26  0.2576   0.6    0.1642   89
# 17376  2012-12-31  0.26  0.2576   0.6    0.1642   90
# 17377  2012-12-31  0.26  0.2727  0.56    0.1343   61
# 17378  2012-12-31  0.26  0.2727  0.65    0.1343   49

# %%
hour['temp']
# Out:
# 0        0.24
# 1        0.22
# 2        0.22
# 3        0.24
# 4        0.24
#          ...
# 17374    0.26
# 17375    0.26
# 17376    0.26
# 17377    0.26
# 17378    0.26
# Name: temp, Length: 17379, dtype: object

# %%
hour['hum']
# Out:
# 0        0.81
# 1         0.8
# 2         0.8
# 3        0.75
# 4        0.75
#          ...
# 17374     0.6
# 17375     0.6
# 17376     0.6
# 17377    0.56
# 17378    0.65
# Name: hum, Length: 17379, dtype: object

# %%
hour['temp'].head()
# Out:
# 0    0.24
# 1    0.22
# 2    0.22
# 3    0.24
# 4    0.24
# Name: temp, dtype: object

# %%
hour['temp'][150]
# Out:
# '0.2'

# %%
hour['temp'][150:285]
# Out:
# 150     0.2
# 151     0.2
# 152     0.2
# 153     0.2
# 154     0.2
#        ...
# 280    0.14
# 281    0.14
# 282    0.14
# 283    0.12
# 284    0.12
# Name: temp, Length: 135, dtype: object

# %%
hour['temp'][150:285].head()
# Out:
# 150    0.2
# 151    0.2
# 152    0.2
# 153    0.2
# 154    0.2
# Name: temp, dtype: object

# %%
hour[['temp','cnt']][150:285]
# Out:
#      temp  cnt
# 150   0.2   73
# 151   0.2   50
# 152   0.2   72
# 153   0.2   87
# 154   0.2  187
# ..    ...  ...
# 280  0.14    3
# 281  0.14    4
# 282  0.14    3
# 283  0.12   28
# 284  0.12   72
#
# [135 rows x 2 columns]

# %%
hour.loc[100:112:3, 'temp':'cnt']
# Out:
#      temp   atemp   hum windspeed  cnt
# 100  0.22   0.197  0.37    0.3284  115
# 103  0.26  0.2273  0.33    0.3284   79
# 106   0.3  0.2879  0.28     0.194   62
# 109  0.24  0.2424  0.38    0.1343  169
# 112   0.2   0.197  0.51     0.194   43

# %%
hour.iloc[105:112:3, 0:3]
# Out:
#          dteday  temp   atemp
# 105  2011-01-05   0.3  0.2879
# 108  2011-01-05  0.24  0.2273
# 111  2011-01-05  0.22  0.2273

# %%
hour
# Out:
#            dteday  temp   atemp   hum windspeed  cnt
# 0      2011-01-01  0.24  0.2879  0.81         0   16
# 1      2011-01-01  0.22  0.2727   0.8         0   40
# 2      2011-01-01  0.22  0.2727   0.8         0   32
# 3      2011-01-01  0.24  0.2879  0.75         0   13
# 4      2011-01-01  0.24  0.2879  0.75         0    1
# ...           ...   ...     ...   ...       ...  ...
# 17374  2012-12-31  0.26  0.2576   0.6    0.1642  119
# 17375  2012-12-31  0.26  0.2576   0.6    0.1642   89
0.80.80.80.80.80.80.80.80.80.80.80.80.80.80.80...
# 2      0.80.80.80.80.80.80.80.80.80.80.80.80.80.80.80...
# 3      0.750.750.750.750.750.750.750.750.750.750.750....
# 4      0.750.750.750.750.750.750.750.750.750.750.750....
# ...

# %%
hour=hour.drop(labels = ['windspeed'], axis=1)

# %%
hour.head()
# Out:
#        dteday  temp   atemp  cnt  \
# 0  2011-01-01  0.24  0.2879   16
# 1  2011-01-01  0.22  0.2727   40
# 2  2011-01-01  0.22  0.2727   32
# 3  2011-01-01  0.24  0.2879   13
# 4  2011-01-01  0.24  0.2879    1
#
#                                                 hum2
# 0  0.810.810.810.810.810.810.810.810.810.810.810....
# 1  0.80.80.80.80.80.80.80.80.80.80.80.80.80.80.80...
# 2  0.80.80.80.80.80.80.80.80.80.80.80.80.80.80.80...
# 3  0.750.750.750.750.750.750.750.750.750.750.750....
# 4  0.750.750.750.750.750.750.750.750.750.750.750....

# %%
hour.shape
# Out:
# (17379, 5)

# %%
hour.isna()
# Out:
#        dteday   temp  atemp    cnt   hum2
# 0       False  False  False  False  False
# 1       False  False  False  False  False
# 2       False  False  False  False  False
# 3       False  False  False  False  False
# 4       False  False  False  False  False
# ...       ...    ...    ...    ...    ...
# 17374   False  False  False  False  False
# 17375   False  False  False  False  False
# 17376   False  False  False  False  False
# 17377   False  False  False  False  False
# 17378   False  False  False  False  False
#
# [17379 rows x 5 columns]

# %%
hour.isna().sum()
# Out:
# dteday    0
# temp      0
# atemp     0
# cnt       0
# hum2      0
# dtype: int64

# %%
hour=hour.dropna()

# %%
hour
# Out:
#            dteday  temp   atemp  cnt  \
# 0      2011-01-01  0.24  0.2879   16
# 1      2011-01-01  0.22  0.2727   40
# 2      2011-01-01  0.22  0.2727   32
# 3      2011-01-01  0.24  0.2879   13
# 4      2011-01-01  0.24  0.2879    1
# ...           ...   ...     ...  ...
# 17374  2012-12-31  0.26  0.2576  119
# 17375  2012-12-31  0.26  0.2576   89
# 17376  2012-12-31  0.26  0.2576   90
# 17377  2012-12-31  0.26  0.2727   61
# 17378  2012-12-31  0.26  0.2727   49
#
#                                                     hum2
# 0      0.810.810.810.810.810.810.810.810.810.810.810....
# 1      0.80.80.80.80.80.80.80.80.80.80.80.80.80.80.80...
# 2      0.80.80.80.80.80.80.80.80.80.80.80.80.80.80.80...
# 3      0.750.750.750.750.750.750.750.750.750.750.750....
# 4      0.750.750.750.750.750.750.750.750.750.750.750....
# ...                                                  ...
# 17374  0.60.60.60.60.60.60.60.60.60.60.60.60.60.60.60...
# ...

# %%
hour['temp'].head()
# Out:
# 0    0.24
# 1    0.22
# 2    0.22
# 3    0.24
# 4    0.24
# Name: temp, dtype: object

# %%
hour.temp.head()
# Out:
# 0    0.24
# 1    0.22
# 2    0.22
# 3    0.24
# 4    0.24
# Name: temp, dtype: object

# %%
hour
# Out:
#            dteday  temp   atemp  cnt  \
# 0      2011-01-01  0.24  0.2879   16
# 1      2011-01-01  0.22  0.2727   40
# 2      2011-01-01  0.22  0.2727   32
# 3      2011-01-01  0.24  0.2879   13
# 4      2011-01-01  0.24  0.2879    1
# ...           ...   ...     ...  ...
# 17374  2012-12-31  0.26  0.2576  119
# 17375  2012-12-31  0.26  0.2576   89
# 17376  2012-12-31  0.26  0.2576   90
# 17377  2012-12-31  0.26  0.2727   61
# 17378  2012-12-31  0.26  0.2727   49
#
#                                                     hum2
# 0      0.810.810.810.810.810.810.810.810.810.810.810....
# 1      0.80.80.80.80.80.80.80.80.80.80.80.80.80.80.80...
# 2      0.80.80.80.80.80.80.80.80.80.80.80.80.80.80.80...
# 3      0.750.750.750.750.750.750.750.750.750.750.750....
# 4      0.750.750.750.750.750.750.750.750.750.750.750....
# ...                                                  ...
# 17374  0.60.60.60.60.60.60.60.60.60.60.60.60.60.60.60...
# ...

# %%
req_col
# Out:
# ['dteday', 'temp', 'atemp', 'hum', 'windspeed', 'cnt']
